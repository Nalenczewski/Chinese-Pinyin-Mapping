# %% [markdown]
# ### Create a dataframe containing pinyin of each character

# %%
import pandas as pd

with open('Unihan_Readings.txt') as file:
    lines = file.read().splitlines()

languages = ['kHanyuPinlu', 'kHanyuPinyin',
             'kMandarin', 'kTGHZ2013', 'kXHC1983']
cols = ['Unicode', 'Char', 'Language', 'Pinyin']

pron_list = [line.strip().split('\t') for line in lines]
pron_list = [[item.strip() for item in line] for line in pron_list]
pron_list = [line for line in pron_list if line[1] in languages]
pron_list = [[line[0],chr(eval('0x'+line[0][2:])), line[1], line[2]] for line in pron_list]

df = pd.DataFrame(pron_list,columns=cols)
#drop duplicate characters

df.sample(10)
# Out:
#        Unicode Char      Language         Pinyin
# 73470  U+21E03    𡸃     kMandarin           xiǎn
# 93745  U+2939C    𩎜     kMandarin            pēi
# 5780    U+42BE    䊾  kHanyuPinyin   53369.080:mù
# 80281  U+24B37    𤬷     kMandarin             nà
# 58881   U+8FDE    连     kTGHZ2013   219.020:lián
# 79413  U+24639    𤘹     kMandarin             pí
# 39342   U+746D    瑭      kXHC1983  1118.020:táng
# 52283   U+8655    處     kMandarin            chù
# 7823    U+478B    䞋     kMandarin           chèn
# 37582   U+7213    爓     kMandarin            yàn

# %% [markdown]
# ### Prune the Pinyin column to only contain pronunciations

# %%
def map_to_dict1(pinyin):
    pin_dict = {pinyin:1}
    return pin_dict

def map_to_dict2(pinyin):
    pins = pinyin.split(':')[1]
    pins = pins.split(',')
    pin_dict = dict.fromkeys(pins,1)
    return pin_dict

def map_to_dict3(pinyin):
    dirty_pins = pinyin.split(' ')
    clean_pins = [pin.split(':')[1] for pin in dirty_pins]
    pin_dict = dict.fromkeys(clean_pins,1)
    return pin_dict

def pinlu(pinyin):
    pinlus = pinyin.split(',')
    pinlu_dict = {pinlu.split('(')[0]: pinlu.split('(')[1].strip(')') for pinlu in pinlus}
    return pinlu_dict

df.loc[(df['Language'] == 'kMandarin'), 'Pinyin'] = df.loc[(df['Language'] == 'kMandarin')]['Pinyin'].apply(map_to_dict1)
df.loc[(df['Language'] == 'kHanyuPinyin'), 'Pinyin'] = df.loc[(df['Language'] == 'kHanyuPinyin')]['Pinyin'].apply(map_to_dict2)
df.loc[(df['Language'] == 'kTGHZ2013'), 'Pinyin'] = df.loc[(df['Language'] == 'kTGHZ2013')]['Pinyin'].apply(map_to_dict3)
df.loc[(df['Language'] == 'kXHC1983'), 'Pinyin'] = df.loc[(df['Language'] == 'kXHC1983')]['Pinyin'].apply(map_to_dict3)
df.loc[(df['Language'] == 'kHanyuPinlu'), 'Pinyin'] = df.loc[(df['Language'] == 'kHanyuPinlu')]['Pinyin'].apply(pinlu)

df.sample(10)
# Out:
#        Unicode Char     Language                 Pinyin
# 55113   U+8A69    詩  kHanyuPinlu         {'shī': '152'}
# 84600  U+26369    𦍩     kXHC1983              {'gǔ': 1}
# 5426    U+41F2    䇲    kMandarin              {'cè': 1}
# 79068  U+2438B    𤎋    kMandarin             {'cuì': 1}
# 51877   U+85B1    薱    kMandarin             {'duì': 1}
# 93625  U+29322    𩌢    kMandarin             {'suō': 1}
# 21575   U+5C6F    屯     kXHC1983  {'tún': 1, 'zhūn': 1}
# 50294   U+836F    药  kHanyuPinlu         {'yào': '407'}
# 62904   U+95ED    闭    kTGHZ2013              {'bì': 1}
# 27980   U+64DA    據  kHanyuPinlu          {'jù': '805'}

# %% [markdown]
# ### Drop duplicate character entries

# %%
df_cleaned = df.drop_duplicates(subset = 'Char',keep='first')

# %% [markdown]
# ### Export table to file

# %%
df_cleaned.to_csv('Character_Pinyin_Table.tsv', sep='\t', index=False)

# %% [markdown]
# ### Import Character_Pinyin Table

# %%
table = pd.read_csv('Character_Pinyin_Table.tsv', sep='\t').set_index('Unicode')
table.loc[table['Char'] == '然']
# Out:
#         Char     Language                Pinyin
# Unicode
# U+7136     然  kHanyuPinlu  {'rán': '3549) ran'}

# %% [markdown]
# ### Add pinyin to a text one character at a time

# %%
def add_pin_1char(text):
    text_pin = ""
   
    for i in text: 
        if i in table['Char'].values:
            char = table.loc[(table['Char'] == i)]
            pron = char['Pinyin'][0].split(':')[0].strip("{'")
            word_pin = i + "(" + pron + ")"
            text_pin += word_pin
        else:
            word_pin = i
            text_pin += word_pin
    return text_pin

# pass a text to the function
with open('Test.txt') as f:
    text = f.read()

print(add_pin_1char(text))
# Out:
# 冰(bīng)雪(xuě)运(yùn)动(dòng)蔚(wèi)然(rán)成(chéng)风(fēng)，冬(dōng)奥(ào)助(zhù)推(tuī)习(xí)近(jìn)平(píng)体(tǐ)育(yù)强(qiáng)国(guó)梦(mèng)
# AMY QIN
# 2022年(nián)2月(yuè)16日(rì)
# 在(zài)北(běi)京(jīng)的(de)一(yī)个(gè)公(gōng)园(yuán)上(shàng)速(sù)滑(huá)课(kè)，摄(shè)于(yú)上(shàng)月(yuè)。冰(bīng)雪(xuě)运(yùn)动(dòng)热(rè)潮(cháo)正(zhèng)在(zài)中(zhōng)国(guó)出(chū)现(xiàn)。
# 在(zài)北(běi)京(jīng)的(de)一(yī)个(gè)公(gōng)园(yuán)上(shàng)速(sù)滑(huá)课(kè)，摄(shè)于(yú)上(shàng)月(yuè)。冰(bīng)雪(xuě)运(yùn)动(dòng)热(rè)潮(cháo)正(zhèng)在(zài)中(zhōng)国(guó)出(chū)现(xiàn)。 KEVIN FRAYER/GETTY IMAGES
# 北(běi)京(jīng)——在(zài)中(zhōng)国(guó)南(nán)方(fāng)城(chéng)市(shì)广(guǎng)州(zhōu)，虽(suī)然(rán)一(yī)年(nián)中(zhōng)大(dà)部(bù)分(fēn)时(shí)候(hou)天(tiān)气(qì)闷(mèn)热(rè)，但(dàn)儿(r)童(tóng)们(men)正(zhèng)在(zài)甩(shuǎi)掉(diào)拖(tuō)鞋(xié)，穿(chuān)上(shàng)滑(huá)雪(xuě)板(bǎn)，在(zài)室(shì)内(nèi)雪(xuě)坡(pō)上(shàng)滑(huá)雪(xuě)。
# 中(zhōng)国(guó)西(xi)南(nán)部(bù)城(chéng)市(shì)成(chéng)都(dōu)的(de)一(yī)个(gè)室(shì)内(nèi)滑(huá)雪(xuě)场(chǎng)。中(zhōng)国(guó)的(de)目(mù)标(biāo)是(shì)到(dào)2025年(nián)发(fā)展(zhǎn)出(chū)一(yī)个(gè)价(jià)值(zhí)1570亿(yì)美(měi)元(yuán)的(de)冰(bīng)雪(xuě)运(yùn)动(dòng)市(shì)场(chǎng)。
# 中(zhōng)国(guó)西(xi)南(nán)部(bù)城(chéng)市(shì)成(chéng)都(dōu)的(de)一(yī)个(gè)室(shì)内(nèi)滑(huá)雪(xuě)场(chǎng)。中(zhōng)国(guó)的(de)目(mù)标(biāo)是(shì)到(dào)2025年(nián)发(fā)展(zhǎn)出(chū)一(yī)个(gè)价(jià)值(zhí)1570亿(yì)美(měi)元(yuán)的(de)冰(bīng)雪(xuě)运(yùn)动(dòng)市(shì)场(chǎng)。 NOEL CELIS/AGENCE FRANCE-PRESSE — GETTY IMAGES
# 官(guān)员(yuán)们(men)说(shuō)，参(cān)与(yǔ)人(rén)数(shù)是(shì)用(yòng)随(suí)机(jī)抽(chōu)样(yàng)的(de)方(fāng)法(fǎ)计(jì)算(suàn)出(chū)来(lái)的(de)。一(yī)些(xiē)分(fēn)析(xī)人(rén)士(shì)对(duì)这(zhè)些(xiē)数(shù)字(zì)表(biǎo)示(shì)怀(huái)疑(yí)，指(zhǐ)出(chū)参(cān)与(yǔ)运(yùn)动(dòng)的(de)定(dìng)义(yì)很(hěn)模(mó)糊(hu)。
# 尽(jǐn)管(guǎn)如(rú)此(cǐ)，很(hěn)少(shǎo)有(yǒu)人(rén)怀(huái)疑(yí)这(zhè)场(chǎng)运(yùn)动(dòng)已(yǐ)产(chǎn)生(shēng)了(le)影(yǐng)响(xiǎng)。据(jù)最(zuì)近(jìn)的(de)一(yī)份(fèn)行(xíng)业(yè)报(bào)告(gào)，中(zhōng)国(guó)滑(huá)雪(xuě)场(chǎng)2019年(nián)度(dù)的(de)滑(huá)雪(xuě)人(rén)次(cì)超(chāo)过(guò)了(le)2000万(wàn)，是(shì)2014年(nián)度(dù)的(de)两(liǎng)倍(bèi)，中(zhōng)国(guó)的(de)滑(huá)雪(xuě)人(rén)次(cì)五(wǔ)年(nián)平(píng)均(jūn)数(shù)是(shì)美(měi)国(guó)的(de)三(sān)分(fēn)之(zhī)一(yī)。中(zhōng)国(guó)的(de)目(mù)标(biāo)是(shì)到(dào)2025年(nián)时(shí)形(xíng)成(chéng)一(yī)个(gè)价(jià)值(zhí)1570亿(yì)美(měi)元(yuán)的(de)冰(bīng)雪(xuě)运(yùn)动(dòng)市(shì)场(chǎng)，这(zhè)与(yǔ)2020年(nián)的(de)全(quán)球(qiú)冰(bīng)雪(xuě)运(yùn)动(dòng)市(shì)场(chǎng)价(jià)值(zhí)几(jǐ)乎(hu)相(xiāng)当(dāng)。
#
# 新(xīn)闻(wén)简(jiǎn)报(bào)：欢(huan)迎(yíng)订(dìng)阅(yuè)新(xīn)闻(wén)简(jiǎn)报(bào)，包(bāo)括(kuò)每(měi)周(zhōu)四(sì)由(yóu)华(huá)文(wén)记(jì)者(zhě)荣(róng)筱(xiǎo)箐(jīng)撰(zhuàn)写(xiě)的(de)“海(hǎi)外(wài)华(huá)人(rén)札(zhá)记(jì)”专(zhuān)栏(lán)，获(huò)取(qǔ)全(quán)球(qiú)重(zhòng)大(dà)资(zī)讯(xùn)，了(le)解(jiě)美(měi)国(guó)华(huá)人(rén)社(shè)区(qū)热(rè)点(diǎn)话(huà)题(tí)。
#
#
# 在(zài)北(běi)京(jīng)周(zhōu)边(biān)的(de)滑(huá)雪(xuě)场(chǎng)，带(dài)有(yǒu)图(tú)勒(lēi)滑(huá)雪(xuě)板(bǎn)架(jià)的(de)汽(qì)车(chē)已(yǐ)开(kāi)始(shǐ)在(zài)停(tíng)车(chē)场(chǎng)出(chū)现(xiàn)。温(wēn)泉(quán)、火(huǒ)锅(guō)、卡(kǎ)拉(lā)OK等(děng)中(zhōng)国(guó)特(tè)色(sè)的(de)滑(huá)雪(xuě)后(hòu)社(shè)交(jiāo)娱(yú)乐(lè)文(wén)化(huà)正(zhèng)在(zài)兴(xìng)起(qǐ)。
# 对(duì)冬(dōng)季(jì)运(yùn)动(dòng)的(de)狂(kuáng)热(rè)不(bù)仅(jǐn)限(xiàn)于(yú)双(shuāng)板(bǎn)滑(huá)雪(xuě)。人(rén)们(men)对(duì)单(dān)板(bǎn)滑(huá)雪(xuě)、冰(bīng)球(qiú)、花(huā)样(yàng)滑(huá)冰(bīng)和(hé)冰(bīng)壶(hú)运(yùn)动(dòng)的(de)兴(xìng)趣(qù)也(yě)在(zài)激(jī)增(zēng)。
# 2018年(nián)，俄(é)罗(luō)斯(sī)总(zǒng)统(tǒng)普(pǔ)京(jīng)和(hé)中(zhōng)国(guó)领(lǐng)导(dǎo)人(rén)习(xí)近(jìn)平(píng)在(zài)中(zhōng)俄(é)青(qīng)年(nián)冰(bīng)球(qiú)队(duì)友(you)谊(yì)赛(sài)开(kāi)球(qiú)。
# 2018年(nián)，俄(é)罗(luō)斯(sī)总(zǒng)统(tǒng)普(pǔ)京(jīng)和(hé)中(zhōng)国(guó)领(lǐng)导(dǎo)人(rén)习(xí)近(jìn)平(píng)在(zài)中(zhōng)俄(é)青(qīng)年(nián)冰(bīng)球(qiú)队(duì)友(you)谊(yì)赛(sài)开(kāi)球(qiú)。 POOL PHOTO BY ALEXEI DRUZHININ
# 2007年(nián)，41岁(suì)的(de)荆(jīng)刚(gāng)从(cóng)芬(fēn)兰(lán)回(huí)到(dào)老(lǎo)家(jiā)天(tiān)津(jīn)，他(tā)发(fā)现(xiàn)那(nà)里(lǐ)只(zhǐ)有(yǒu)两(liǎng)个(gè)小(xiǎo)型(xíng)冰(bīng)场(chǎng)，而(ér)且(qiě)人(rén)们(men)对(duì)冰(bīng)球(qiú)几(jǐ)乎(hu)一(yī)无(wú)所(suǒ)知(zhī)，这(zhè)让(ràng)他(tā)感(gǎn)到(dào)失(shī)望(wàng)。他(tā)在(zài)国(guó)外(wài)读(dú)书(shū)时(shí)爱(ài)上(shàng)了(le)冰(bīng)球(qiú)运(yùn)动(dòng)。
# “我(wǒ)有(yǒu)带(dài)着(zhe)冰(bīng)球(qiú)棍(gùn)出(chū)门(mén)的(de)习(xí)惯(guàn)，人(rén)们(men)会(huì)停(tíng)下(xià)来(lái)问(wèn)我(wǒ)，‘你(nǐ)是(shì)去(qù)钓(diào)鱼(yú)吗(ma)？’”荆(jīng)先(xiān)生(shēng)回(huí)忆(yì)道(dào)。他(tā)说(shuō)，大(dà)家(jiā)“认(rèn)为(wèi)冰(bīng)球(qiú)是(shì)一(yī)项(xiàng)打(dǎ)架(jià)运(yùn)动(dòng)，非(fēi)常(cháng)暴(bào)力(lì)”。
# 仅(jǐn)十(shí)多(duō)年(nián)后(hòu)的(de)今(jīn)天(tiān)，天(tiān)津(jīn)已(yǐ)拥(yōng)有(yǒu)三(sān)个(gè)大(dà)型(xíng)冰(bīng)球(qiú)场(chǎng)和(hé)一(yī)个(gè)由(yóu)大(dà)约(yuē)20支(zhī)球(qiú)队(duì)组(zǔ)成(chéng)的(de)完(wán)整(zhěng)的(de)青(qīng)少(shǎo)年(nián)联(lián)赛(sài)。荆(jīng)先(xiān)生(shēng)现(xiàn)在(zài)经(jīng)营(yíng)着(zhe)其(qí)中(zhōng)一(yī)家(jiā)冰(bīng)球(qiú)场(chǎng)，他(tā)说(shuō)，冰(bīng)球(qiú)运(yùn)动(dòng)在(zài)中(zhōng)国(guó)各(gè)地(de)的(de)城(chéng)市(shì)已(yǐ)越(yuè)来(lái)越(yuè)受(shòu)欢(huan)迎(yíng)。
# 研(yán)究(jiū)中(zhōng)国(guó)滑(huá)雪(xuě)历(lì)史(shǐ)的(de)单(dān)兆(zhào)鉴(jiàn)把(bǎ)习(xí)近(jìn)平(píng)的(de)运(yùn)动(dòng)与(yǔ)毛(máo)泽(zé)东(dōng)领(lǐng)导(dǎo)的(de)类(lèi)似(shì)努(nǔ)力(lì)进(jìn)行(xíng)了(le)比(bǐ)较(jiào)，毛(máo)泽(zé)东(dōng)认(rèn)为(wèi)大(dà)众(zhòng)参(cān)与(yǔ)体(tǐ)育(yù)活(huó)动(dòng)对(duì)一(yī)个(gè)健(jiàn)康(kāng)的(de)工(gōng)人(rén)阶(jiē)级(jí)必(bì)不(bù)可(kě)少(shǎo)。
# “建(jiàn)设(shè)一(yī)个(gè)强(qiáng)大(dà)的(de)国(guó)家(jiā)，需(xū)要(yào)至(zhì)少(shǎo)有(yǒu)强(qiáng)壮(zhuàng)的(de)身(shēn)体(tǐ)，”单(dān)兆(zhào)鉴(jiàn)提(tí)到(dào)习(xí)近(jìn)平(píng)的(de)想(xiǎng)法(fǎ)时(shí)说(shuō)。
#
# 在(zài)更(gèng)热(rè)的(de)中(zhōng)国(guó)南(nán)方(fāng)地(de)区(qū)，解(jiě)决(jué)办(bàn)法(fǎ)是(shì)建(jiàn)造(zào)室(shì)内(nèi)滑(huá)雪(xuě)场(chǎng)。广(guǎng)州(zhōu)融(róng)创(chuàng)雪(xuě)世(shì)界(jiè)是(shì)全(quán)球(qiú)第(dì)二(èr)大(dà)室(shì)内(nèi)滑(huá)雪(xuě)场(chǎng)，有(yǒu)四(sì)条(tiáo)人(rén)造(zào)雪(xuě)道(dào)，长(zhǎng)达(dá)460米(mǐ)。该(gāi)室(shì)内(nèi)滑(huá)雪(xuě)场(chǎng)一(yī)个(gè)大(dà)型(xíng)综(zōng)合(hé)体(tǐ)的(de)一(yī)部(bù)分(fēn)，还(hái)包(bāo)括(kuò)一(yī)个(gè)水(shuǐ)世(shì)界(jiè)、一(yī)个(gè)主(zhǔ)题(tí)公(gōng)园(yuán)和(hé)几(jǐ)家(jiā)酒(jiǔ)店(diàn)。
# 但(dàn)不(bù)少(shǎo)冰(bīng)雪(xuě)运(yùn)动(dòng)仍(réng)超(chāo)过(guò)大(dà)众(zhòng)的(de)支(zhī)付(fù)能(néng)力(lì)。滑(huá)雪(xuě)缆(lǎn)车(chē)的(de)票(piào)价(jià)最(zuì)高(gāo)可(kě)达(dá)700元(yuán)，购(gòu)买(mǎi)全(quán)套(tào)冰(bīng)球(qiú)装(zhuāng)备(bèi)可(kě)能(néng)需(xū)要(yào)2.5万(wàn)元(yuán)，这(zhè)在(zài)人(rén)均(jūn)可(kě)支(zhī)配(pèi)收(shōu)入(rù)中(zhōng)位(wèi)数(shù)仅(jǐn)略(lüè)高(gāo)于(yú)2.7万(wàn)元(yuán)的(de)国(guó)家(jiā)是(shì)一(yī)笔(bǐ)大(dà)钱(qián)。
# 在(zài)美(měi)国(guó)出(chū)生(shēng)的(de)自(zì)由(yóu)式(shì)滑(huá)雪(xuě)运(yùn)动(dòng)员(yuán)谷(gǔ)爱(ài)凌(lìng)的(de)海(hǎi)报(bào)，她(tā)正(zhèng)在(zài)北(běi)京(jīng)代(dài)表(biǎo)她(tā)母(mǔ)亲(qīn)的(de)祖(zǔ)国(guó)中(zhōng)国(guó)参(cān)赛(sài)。
# 在(zài)美(měi)国(guó)出(chū)生(shēng)的(de)自(zì)由(yóu)式(shì)滑(huá)雪(xuě)运(yùn)动(dòng)员(yuán)谷(gǔ)爱(ài)凌(lìng)的(de)海(hǎi)报(bào)，她(tā)正(zhèng)在(zài)北(běi)京(jīng)代(dài)表(biǎo)她(tā)母(mǔ)亲(qīn)的(de)祖(zǔ)国(guó)中(zhōng)国(guó)参(cān)赛(sài)。 KEVIN FRAYER/GETTY IMAGES
# 费(fèi)用(yòng)只(zhǐ)是(shì)一(yī)个(gè)潜(qián)在(zài)的(de)障(zhàng)碍(ài)；许(xǔ)多(duō)中(zhōng)国(guó)人(rén)也(yě)认(rèn)为(wèi)冰(bīng)雪(xuě)运(yùn)动(dòng)太(tài)危(wēi)险(xiǎn)，这(zhè)个(gè)印(yìn)象(xiàng)并(bìng)不(bù)一(yī)定(dìng)错(cuò)的(de)。
# 在(zài)一(yī)个(gè)缺(quē)少(shǎo)合(hé)格(gé)教(jiào)练(liàn)的(de)国(guó)家(jiā)，受(shòu)伤(shāng)往(wǎng)往(wǎng)不(bù)可(kě)避(bì)免(miǎn)。中(zhōng)国(guó)1300万(wàn)滑(huá)雪(xuě)者(zhě)中(zhōng)，80%以(yǐ)上(shàng)是(shì)初(chū)学(xué)者(zhě)。许(xǔ)多(duō)新(xīn)手(shǒu)将(jiāng)毛(máo)绒(róng)动(dòng)物(wù)玩(wán)具(jù)——大(dà)多(duō)是(shì)乌(wū)龟(guī)，但(dàn)也(yě)有(yǒu)其(qí)他(tā)卡(kǎ)通(tōng)动(dòng)物(wù)——绑(bǎng)在(zài)屁(pì)股(gǔ)上(shàng)，以(yǐ)便(biàn)摔(shuāi)倒(dào)时(shí)起(qǐ)缓(huǎn)冲(chōng)作(zuò)用(yòng)，同(tóng)时(shí)提(tí)醒(xǐng)山(shān)上(shàng)的(de)其(qí)他(tā)人(rén)保(bǎo)持(chí)距(jù)离(lí)。
# 由(yóu)于(yú)担(dān)心(xīn)摔(shuāi)倒(dào)，26岁(suì)的(de)北(běi)京(jīng)教(jiào)育(yù)顾(gù)问(wèn)布(bù)兰(lán)·杨(yáng)上(shàng)第(dì)一(yī)次(cì)堂(táng)单(dān)板(bǎn)滑(huá)雪(xuě)课(kè)时(shí)，选(xuǎn)择(zé)了(le)像(xiàng)是(shì)一(yī)个(gè)没(méi)有(yǒu)雪(xuě)的(de)巨(jù)型(xíng)下(xià)坡(pō)跑(pǎo)步(bù)机(jī)的(de)人(rén)造(zào)“干(gàn)”道(dào)。他(tā)对(duì)滑(huá)雪(xuě)的(de)热(rè)情(qíng)来(lái)自(zì)他(tā)在(zài)抖(dǒu)音(yīn)上(shàng)看(kàn)到(dào)的(de)滑(huá)雪(xuě)板(bǎn)运(yùn)动(dòng)的(de)视(shì)频(pín)，也(yě)来(lái)自(zì)出(chū)现(xiàn)在(zài)中(zhōng)国(guó)广(guǎng)告(gào)上(shàng)的(de)美(měi)籍(jí)华(huá)人(rén)滑(huá)雪(xuě)明(míng)星(xīng)谷(gǔ)爱(ài)凌(lìng)。
# 杨(yáng)先(xiān)生(shēng)说(shuō)，他(tā)希(xī)望(wàng)不(bù)久(jiǔ)能(néng)升(shēng)级(jí)到(dào)初(chū)级(jí)道(dào)，在(zài)真(zhēn)正(zhèng)的(de)雪(xuě)道(dào)上(shàng)首(shǒu)次(cì)试(shì)试(shì)自(zì)己(jǐ)的(de)新(xīn)技(jì)能(néng)。他(tā)会(huì)把(bǎ)乌(wū)龟(guī)绑(bǎng)在(zài)下(xià)身(shēn)吗(ma)？
# 目(mù)前(qián)还(hái)不(bù)清(qīng)楚(chu)冬(dōng)奥(ào)会(huì)结(jié)束(shù)后(hòu)人(rén)们(men)对(duì)冰(bīng)雪(xuě)运(yùn)动(dòng)的(de)热(rè)情(qíng)是(shì)否(fǒu)还(hái)会(huì)继(jì)续(xù)。一(yī)些(xiē)冰(bīng)场(chǎng)已(yǐ)陷(xiàn)入(rù)失(shī)修(xiū)状(zhuàng)态(tài)，一(yī)些(xiē)较(jiào)小(xiǎo)的(de)滑(huá)雪(xuě)场(chǎng)已(yǐ)关(guān)门(mén)。但(dàn)专(zhuān)家(jiā)说(shuō)，该(gāi)行(xíng)业(yè)出(chū)现(xiàn)合(hé)并(bìng)是(shì)意(yì)料(liào)之(zhī)中(zhōng)的(de)。
# 张(zhāng)家(jiā)口(kǒu)滑(huá)雪(xuě)场(chǎng)的(de)滑(huá)雪(xuě)板(bǎn)出(chū)租(zū)。
# 张(zhāng)家(jiā)口(kǒu)滑(huá)雪(xuě)场(chǎng)的(de)滑(huá)雪(xuě)板(bǎn)出(chū)租(zū)。 KEVIN FRAYER/GETTY IMAGES
# 对(duì)天(tiān)津(jīn)的(de)冰(bīng)场(chǎng)经(jīng)理(lǐ)荆(jīng)先(xiān)生(shēng)来(lái)说(shuō)，主(zhǔ)要(yào)目(mù)标(biāo)之(zhī)一(yī)是(shì)提(tí)倡(chàng)体(tǐ)育(yù)运(yùn)动(dòng)的(de)精(jīng)神(shén)，他(tā)也(yě)在(zài)自(zì)己(jǐ)的(de)博(bó)客(kè)“冰(bīng)球(qiú)老(lǎo)爹(diē)”上(shàng)写(xiě)关(guān)于(yú)冰(bīng)球(qiú)的(de)文(wén)章(zhāng)。
# “为(wèi)他(tā)们(men)加(jiā)油(yóu)取(qǔ)代(dài)盲(máng)目(mù)督(dū)促(cù)，”荆(jīng)先(xiān)生(shēng)在(zài)最(zuì)近(jìn)一(yī)篇(piān)针(zhēn)对(duì)其(qí)他(tā)中(zhōng)国(guó)冰(bīng)球(qiú)家(jiā)长(zhǎng)的(de)文(wén)章(zhāng)中(zhōng)写(xiě)道(dào)。“我(wǒ)们(men)作(zuò)为(wèi)冰(bīng)球(qiú)老(lǎo)爹(diē)老(lǎo)妈(mā)的(de)最(zuì)主(zhǔ)要(yào)的(de)目(mù)标(biāo)应(yīng)该(gāi)是(shì)：为(wèi)孩(hái)子(zi)们(men)注(zhù)入(rù)他(tā)们(men)所(suǒ)热(rè)爱(ài)运(yùn)动(dòng)的(de)激(jī)情(qíng)。”

# %% [markdown]
# ### Import a phrase dictionary

# %%
phrase = pd.read_csv('phrase.txt', sep='=',names=['Char','Pron'])
phrase.sample(10)
# Out:
#          Char                      Pron
# 27199      好客                    hào,kè
# 2823       东北                  dōng,běi
# 47370  无线电接收机  wú,xiàn,diàn,jiē,shōu,jī
# 15980     卤代烃               lǔ,dài,tīng
# 20359      和蔼                     hé,ǎi
# 3830       丰姿                   fēng,zī
# 70933      纵梁                zòng,liáng
# 22052      回馈                   huí,kuì
# 68421     稻草人               dào,cǎo,rén
# 3725      中纪委              zhōng,jì,wěi

# %% [markdown]
# ### Use the phrase dictionary to add pinyin to chracters two at a time

# %%
phrase = phrase.set_index('Char')

# %%
# define function to add pinyin to all characters in a text, two characters at a time
def add_pin_2char(text):
    text_pin = ""
    
    i=0
    while i < len(text)-1:
        if text[i:i+2] in phrase.index: 
            char = phrase.loc[text[i:i+2]]
            pron = char['Pron'].split(",")
            word_pin = text[i] + '(' + pron[0] + ')' + text[i+1] + '(' + pron[1] + ')' 
            text_pin += word_pin
            i += 2
        elif text[i] in table['Char'].values:
            char = table.loc['U+'+hex(ord(text[i])).upper()[2:]]
            pron = list(eval(char['Pinyin']).keys())[0]
            word_pin = text[i] + "(" + pron + ")"
            text_pin += word_pin
            i += 1
        else:
            word_pin = text[i]
            text_pin += word_pin
            i += 1

    return text_pin

# pass a text to the function
with open('Baidu.txt') as f:
    text = f.read()

print(add_pin_2char(text))
# Out:
# 中(zhōng)国(guó)历(lì)史(shǐ)上(shàng)的(de)重(zhòng)大(dà)事(shì)件(jiàn)，你(nǐ)知(zhī)道(dào)几(jǐ)件(jiàn)？
#
# 如(rú)果(guǒ)直(zhí)留(liú)下(xià)妹(mèi)
#
# 发(fā)布(bù)时(shí)间(jiān): 2021-12-02 16:51
# 关(guān)注(zhù)
# 1、秦(qín)始(shǐ)皇(huáng)统(tǒng)一(yī)中(zhōng)国(guó)
#
# 秦(qín)始(shǐ)皇(huáng)是(shì)出(chū)生(shēng)于(yú)赵(zhào)国(guó)都(dū)城(chéng)邯(hán)郸(dān)，前(qián)247年(nián)，13岁(suì)时(shí)即(jí)王(wáng)位(wèi)。22岁(suì)时(shí)，开(kāi)始(shǐ)“亲(qīn)理(lǐ)朝(cháo)政(zhèng)”，自(zì)前(qián)230年(nián)至(zhì)前(qián)221年(nián)，先(xiān)后(hòu)灭(miè)韩(hán)、赵(zhào)、魏(wèi)、楚(chu)、燕(yàn)、齐(qí)六(liù)国(guó)，39岁(suì)时(shí)完(wán)成(chéng)了(le)统(tǒng)一(yī)中(zhōng)国(guó)大(dà)业(yè)，建(jiàn)立(lì)起(qǐ)一(yī)个(gè)以(yǐ)汉(hàn)族(zú)为(wéi)主(zhǔ)体(tǐ)统(tǒng)一(yī)的(de)中(zhōng)央(yāng)集(jí)权(quán)的(de)强(qiáng)大(dà)国(guó)家(jiā)——秦(qín)朝(cháo)，并(bìng)奠(diàn)定(dìng)中(zhōng)国(guó)本(běn)土(tǔ)的(de)疆(jiāng)域(yù)。秦(qín)王(wáng)政(zhèng)灭(miè)六(liù)国(guó)后(hòu)，认(rèn)为(wéi)自(zì)己(jǐ)“德(dé)兼(jiān)三(sān)皇(huáng)，功(gōng)过(guò)五(wǔ)帝(dì)”，遂(suì)采(cǎi)用(yòng)三(sān)皇(huáng)之(zhī)“皇(huáng)”、五(wǔ)帝(dì)之(zhī)“帝(dì)”构(gòu)成(chéng)“皇(huáng)帝(dì)”的(de)称(chēng)号(hào)，是(shì)中(zhōng)国(guó)历(lì)史(shǐ)上(shàng)第(dì)一(yī)个(gè)使(shǐ)用(yòng)“皇(huáng)帝(dì)”称(chēng)号(hào)的(de)君(jūn)主(zhǔ)，所(suǒ)以(yǐ)自(zì)称(chēng)“始(shǐ)皇(huáng)帝(dì)”。
